# %%
import pandas as pd
from frust.vis import plot_regression_outliers

# %%
df_dft_ts3 = pd.read_csv("misc/ts3_dG_final.csv", index_col=0)
df_dft_ts4 = pd.read_csv("misc/ts4_dG_final.csv", index_col=0)
df_all_xtb = pd.read_csv("misc/all_xtb_sps.csv", index_col=0)

# %%
df_dft_ts3 = df_dft_ts3.merge(df_all_xtb)[["ligand_name", "rpos", "dG", "dE_ts3"]]
df_dft_ts4 = df_dft_ts4.merge(df_all_xtb)[["ligand_name", "rpos", "dG", "dE_ts4"]]

# %%
plot_regression_outliers(df_dft_ts3, y_col="dE_ts3")
# Out:
# [INFO]: Linear relation: y = 0.564223x + 0.056511

# %%
plot_regression_outliers(df_dft_ts4, y_col="dE_ts4")
y = 0.615084x - 4.040237

y + 4.040237 = 0.615084x

x = (y + 4.040237) / x
# Out:
# [INFO]: Linear relation: y = 0.615084x - 4.040237
