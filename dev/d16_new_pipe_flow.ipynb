# %%
# %load_ext autoreload
# %autoreload 2

# %%
import frust.pipes as fp

# %%
ts_structs = fp.setup_ts(["CN1C=CC=C1",], "../structures/ts1.xyz")

# %%
ts_structs
# Out:
# [{'TS1(1-methylpyrrole_rpos(2))': (<rdkit.Chem.rdchem.RWMol at 0x7fc089d03e20>,
#    [10, 11, 39, 40, 41, 44],
#    'CN1C=CC=C1')},
#  {'TS1(1-methylpyrrole_rpos(3))': (<rdkit.Chem.rdchem.RWMol at 0x7fc089d03650>,
#    [10, 11, 39, 40, 41, 45],
#    'CN1C=CC=C1')}]

# %%
fp.run_ts_per_rpos(ts_structs[0],
                   n_confs=2,
                   debug=False,
                   save_output_dir=False)
# Out:
# Embedded 2 conformers on atom 44
# 2025-06-26 13:47:49 INFO  frust.stepper: [xtb-gfnff-opt] row 0 (TS1(1-methylpyrrole_rpos(2)))…
# 2025-06-26 13:47:51 INFO  frust.stepper: [xtb-gfnff-opt] row 1 (TS1(1-methylpyrrole_rpos(2)))…
# 2025-06-26 13:47:51 INFO  frust.stepper: [xtb-gfn] row 0 (TS1(1-methylpyrrole_rpos(2)))…
# 2025-06-26 13:47:51 INFO  frust.stepper: [xtb-gfn] row 1 (TS1(1-methylpyrrole_rpos(2)))…
# 2025-06-26 13:47:52 INFO  frust.stepper: [xtb-gfn-opt] row 0 (TS1(1-methylpyrrole_rpos(2)))…
# 2025-06-26 13:48:07 INFO  frust.stepper: [xtb-gfn-opt] row 1 (TS1(1-methylpyrrole_rpos(2)))…
#                     custom_name      ligand_name  rpos  \
# 0  TS1(1-methylpyrrole_rpos(2))  1-methylpyrrole     2
#
#            constraint_atoms  cid      smiles  \
# 0  [10, 11, 39, 40, 41, 44]    0  CN1C=CC=C1
#
#                                                atoms  \
# 0  [C, C, C, C, C, C, H, H, H, H, B, N, C, C, C, ...
#
# ...
