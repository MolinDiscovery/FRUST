# %%
from frust.stepper import Stepper
import pandas as pd

step = Stepper(["CO"], save_output_dir=True)

df = pd.read_parquet("../analysis/output_files/04_ts3_TMP.parquet")
step.orca(df.iloc[[0]], options={"HF-3c": None})
# Out:
# 2025-07-30 15:18:37 INFO  frust.stepper: Working dir: .
# 2025-07-30 15:18:37 INFO  frust.stepper: [orca-HF-3c] row 0 (TS3(1-methylpyrrole_rpos(2)))…
#                     custom_name      ligand_name  rpos  \
# 0  TS3(1-methylpyrrole_rpos(2))  1-methylpyrrole     2
#
#            constraint_atoms  cid      smiles  \
# 0  [10, 12, 11, 41, 40, 64]  194  CN1C=CC=C1
#
#                                                atoms  \
# 0  [C, C, C, C, C, C, H, H, H, H, B, H, N, C, C, ...
#
#                                      coords_embedded  energy_uff  \
# 0  [[2.276239185038138, -3.9917397186743226, 1.13...  9776.17156
#
#    xtb-gfnff-opt-electronic_energy  ...  \
# 0                       -12.128386  ...
#
#    DFT-pre-SP-wB97X-D3-6-31+G**-NoSym-normal_termination  \
# 0                                               True
#
#   DFT-wB97X-D3-6-31G**-OptTS-electronic_energy  \
# 0                                  -1325.54111
#
#    DFT-wB97X-D3-6-31G**-OptTS-gibbs_energy  \
# ...
