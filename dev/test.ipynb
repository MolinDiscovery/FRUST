# %%
from pathlib import Path
from tooltoad.chemutils import xyz2ac    

f = Path("../structures/ts4_TMP.xyz")
mols = {}
with open(f, "r") as file:
    xyz_block = file.read()
    # mol = xyz2mol(xyz_block)
    # mols[f.stem] = (mol, [0])
    atoms, coords = xyz2ac(xyz_block)

from tooltoad.orca import orca_calculate
orca_calculate(atoms, coords, options={"AM6": None}, calc_dir="noob")
# Out:
# Orca calculation did not terminate normally.
# {'normal_termination': False,
#  'log': '',
#  'calc_dir': '/lustre/hpc/kemi/jmni/dev/FRUST/dev/noob',
#  'time': '2025-09-03 11:21:36',
#  'timestamp': 1756891296.245732,
#  'atoms': ['C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'H',
#   'H',
#   'H',
#   'H',
#   'N',
#   'B',
#   'H',
#   'H',
#   'H',
#   'C',
#   'H',
#   'H',
#   'H',
#   'C',
#   'H',
#   'H',
#   'H',
#   'C',
#   'C',
#   'C',
#   'H',
#   'H',
#   'C',
#   'C',
#   'O',
#   'O',
#   'B',
#   'C',
#   'H',
#   'H',
#   'H',
#   'C',
#   'H',
#   'C',
#   'H',
#   'H',
#   'S',
#   'C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'H',
#   'H',
#   'C',
#   'H',
#   'H',
#   'C',
#   'C',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H'],
#  'coords': [[-2.401391, -1.418555, 1.040286],
#   [-1.131797, -0.839282, 1.264193],
#   [-0.000847, -1.574892, 0.861649],
#   [-0.093216, -2.856259, 0.334628],
#   [-1.345961, -3.44047, 0.173544],
#   [-2.480745, -2.716728, 0.51199],
#   [0.982479, -1.124296, 0.979594],
#   [0.80599, -3.394281, 0.046374],
#   [-1.440926, -4.442195, -0.23689],
#   [-3.464396, -3.146111, 0.346689],
#   [-3.611411, -0.705527, 1.302784],
#   [-0.930038, 0.590384, 1.929793],
#   [1.110258, 4.161468, 0.818937],
#   [2.644035, 3.719264, 0.041437],
#   [1.327366, 2.53585, 0.15908],
#   [3.92574, 1.3177, 0.725063],
#   [4.690354, 2.08877, 0.584479],
#   [4.428134, 0.348329, 0.782311],
#   [3.27242, 1.30738, -0.149023],
#   [4.031474, 1.351401, 3.229099],
#   [4.369493, 0.311986, 3.242019],
#   [4.911978, 2.00037, 3.210681],
#   [3.476361, 1.538206, 4.152894],
#   [0.013065, 0.446161, 3.676874],
#   [0.189969, -0.867008, 4.103431],
#   [-0.274503, -1.124208, 5.406425],
#   [-1.848264, 1.263084, 2.280216],
#   [-0.087884, 1.262005, 1.344826],
#   [2.351079, 2.915994, 2.049863],
#   [3.139655, 1.561234, 2.004627],
#   [1.211476, 2.57327, 2.863243],
#   [2.083253, 0.582111, 2.088466],
#   [0.999483, 1.217369, 2.683538],
#   [3.090065, 4.062657, 2.724382],
#   [2.463055, 4.958099, 2.716667],
#   [3.327655, 3.826643, 3.762964],
#   [4.018711, 4.292864, 2.191926],
#   [1.833465, 3.354102, 0.678732],
#   [0.635841, -1.616737, 3.45989],
#   [-0.791952, 0.009145, 5.989236],
#   [-0.238447, -2.090747, 5.893133],
#   [-1.222149, 0.093205, 6.979504],
#   [-0.719273, 1.363805, 4.969583],
#   [-4.219881, 0.082172, 0.20107],
#   [-4.367279, -1.019192, 2.52983],
#   [-5.271267, 0.183746, 2.843347],
#   [-3.393639, -1.182167, 3.703771],
#   [-5.200582, -2.319839, 2.443697],
#   [-6.261688, 0.523727, 1.720328],
#   [-4.609617, 1.037099, 3.030368],
#   [-5.807908, -0.006669, 3.780004],
#   [-5.752654, 0.07544, 0.344256],
#   [-6.448052, 1.60313, 1.721846],
#   [-7.231255, 0.049988, 1.910102],
#   [-3.894155, -0.51879, -1.176387],
#   [-3.707669, 1.53637, 0.200486],
#   [-6.173364, 0.715473, -0.439467],
#   [-6.10556, -0.938185, 0.126038],
#   [-4.262748, -1.545107, -1.263402],
#   [-2.819124, -0.527008, -1.374054],
#   [-4.375432, 0.081378, -1.955532],
#   [-4.187767, 2.112391, -0.599222],
#   [-2.627227, 1.563594, 0.032262],
#   [-3.90336, 2.037269, 1.151881],
#   [-5.8951, -2.318268, 1.600613],
#   [-5.784536, -2.4598, 3.360565],
#   [-4.544031, -3.188574, 2.33739],
#   [-2.704017, -2.015366, 3.542803],
#   [-3.949344, -1.378072, 4.626917],
#   [-2.806368, -0.271521, 3.838432]],
#  'charge': 0,
#  'multiplicity': 1,
#  'options': {'AM6': None}}
